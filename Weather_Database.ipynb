# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
import timeit
import json
# Import the requests library.
import requests

# Import the datetime module from the datetime library.
from datetime import datetime
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#Loop through the cities list.

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 730

# %%
#Initialize an Empty List and Counters

#Build the basic URL for the OpenWeatherMap with your weather_api_key added to the URL.
#Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#print(url)

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
#Group the cities in sets of 50 to log the process as we find the weather data for each city.
# Loop through all the cities in the list.
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
        
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    
    # Add 1 to the record count.
    record_count += 1
    
    #Build the city_url or endpoint for each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    #Make an API request for each city.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse the JSON weather data for the following:
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
        #"Current Description": city_description
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | ponta do sol
# Processing Record 2 of Set 1 | bluff
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | tiksi
# Processing Record 5 of Set 1 | lorengau
# Processing Record 6 of Set 1 | tautira
# Processing Record 7 of Set 1 | cape town
# Processing Record 8 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 1 | chokurdakh
# Processing Record 11 of Set 1 | fairbanks
# Processing Record 12 of Set 1 | mar del plata
# Processing Record 13 of Set 1 | cidreira
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | avarua
# Processing Record 16 of Set 1 | laguna
# Processing Record 17 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | ossora
# Processing Record 20 of Set 1 | unye
# City not found. Skipping...
# Processing Record 21 of Set 1 | victoria
# Processing Record 22 of Set 1 | barrow
# Processing Record 23 of Set 1 | belyy yar
# Processing Record 24 of Set 1 | yellowknife
# Processing Record 25 of Set 1 | besikduzu
# Processing Record 26 of Set 1 | lasa
# Processing Record 27 of Set 1 | honningsvag
# Processing Record 28 of Set 1 | bathsheba
# Processing Record 29 of Set 1 | san andres
# Processing Record 30 of Set 1 | atuona
# Processing Record 31 of Set 1 | saldanha
# Processing Record 32 of Set 1 | carnarvon
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | oran
# Processing Record 35 of Set 1 | port lincoln
# Processing Record 36 of Set 1 | severo-kurilsk
# Processing Record 37 of Set 1 | vaini
# Processing Record 38 of Set 1 | christchurch
# Processing Record 39 of Set 1 | longyearbyen
# Processing Record 40 of Set 1 | arraial do cabo
# Processing Record 41 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 1 | port macquarie
# Processing Record 43 of Set 1 | mataura
# Processing Record 44 of Set 1 | new norfolk
# Processing Record 45 of Set 1 | jamestown
# Processing Record 46 of Set 1 | nikolskoye
# Processing Record 47 of Set 1 | kapaa
# Processing Record 48 of Set 1 | dinhata
# Processing Record 49 of Set 1 | yar-sale
# Processing Record 50 of Set 1 | hithadhoo
# Processing Record 1 of Set 2 | ponot
# Processing Record 2 of Set 2 | awbari
# Processing Record 3 of Set 2 | lebu
# Processing Record 4 of Set 2 | butaritari
# Processing Record 5 of Set 2 | puerto ayora
# Processing Record 6 of Set 2 | beloha
# Processing Record 7 of Set 2 | mikhaylovskoye
# Processing Record 8 of Set 2 | thompson
# Processing Record 9 of Set 2 | paamiut
# Processing Record 10 of Set 2 | cockburn town
# Processing Record 11 of Set 2 | pasni
# Processing Record 12 of Set 2 | kijang
# Processing Record 13 of Set 2 | upernavik
# Processing Record 14 of Set 2 | klyuchi
# Processing Record 15 of Set 2 | karacakoy
# Processing Record 16 of Set 2 | tuktoyaktuk
# Processing Record 17 of Set 2 | haicheng
# Processing Record 18 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 2 | cayenne
# Processing Record 20 of Set 2 | tarakan
# Processing Record 21 of Set 2 | biskamzha
# Processing Record 22 of Set 2 | arcata
# Processing Record 23 of Set 2 | pacific grove
# Processing Record 24 of Set 2 | bairiki
# Processing Record 25 of Set 2 | jurado
# Processing Record 26 of Set 2 | valparaiso
# Processing Record 27 of Set 2 | mongar
# Processing Record 28 of Set 2 | kaeo
# Processing Record 29 of Set 2 | moindou
# Processing Record 30 of Set 2 | ardakan
# Processing Record 31 of Set 2 | stalybridge
# Processing Record 32 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 2 | mut
# Processing Record 34 of Set 2 | chilliwack
# Processing Record 35 of Set 2 | fuxin
# Processing Record 36 of Set 2 | ancud
# Processing Record 37 of Set 2 | bethel
# Processing Record 38 of Set 2 | panara
# Processing Record 39 of Set 2 | port alfred
# Processing Record 40 of Set 2 | bredasdorp
# Processing Record 41 of Set 2 | jamame
# Processing Record 42 of Set 2 | presidente medici
# Processing Record 43 of Set 2 | peniche
# Processing Record 44 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 2 | grand gaube
# Processing Record 46 of Set 2 | sitka
# Processing Record 47 of Set 2 | dubova
# Processing Record 48 of Set 2 | hilo
# Processing Record 49 of Set 2 | quatre cocos
# Processing Record 50 of Set 2 | tawnat
# City not found. Skipping...
# Processing Record 1 of Set 3 | saint-philippe
# Processing Record 2 of Set 3 | vestmanna
# Processing Record 3 of Set 3 | qaanaaq
# Processing Record 4 of Set 3 | borlange
# City not found. Skipping...
# Processing Record 5 of Set 3 | porto torres
# Processing Record 6 of Set 3 | hermanus
# Processing Record 7 of Set 3 | oprisor
# Processing Record 8 of Set 3 | marfino
# Processing Record 9 of Set 3 | saint-pierre
# Processing Record 10 of Set 3 | zhezkazgan
# Processing Record 11 of Set 3 | college
# Processing Record 12 of Set 3 | khatanga
# Processing Record 13 of Set 3 | great yarmouth
# Processing Record 14 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 3 | east london
# Processing Record 16 of Set 3 | nouadhibou
# Processing Record 17 of Set 3 | husavik
# Processing Record 18 of Set 3 | porto belo
# Processing Record 19 of Set 3 | racale
# Processing Record 20 of Set 3 | kopavogur
# Processing Record 21 of Set 3 | geraldton
# Processing Record 22 of Set 3 | kizema
# Processing Record 23 of Set 3 | tawkar
# City not found. Skipping...
# Processing Record 24 of Set 3 | izberbash
# Processing Record 25 of Set 3 | tottori
# Processing Record 26 of Set 3 | bambous virieux
# Processing Record 27 of Set 3 | solnechnyy
# Processing Record 28 of Set 3 | ilulissat
# Processing Record 29 of Set 3 | dingle
# Processing Record 30 of Set 3 | caravelas
# Processing Record 31 of Set 3 | pathein
# Processing Record 32 of Set 3 | kahului
# Processing Record 33 of Set 3 | hobart
# Processing Record 34 of Set 3 | kruisfontein
# Processing Record 35 of Set 3 | asau
# Processing Record 36 of Set 3 | port elizabeth
# Processing Record 37 of Set 3 | holme
# Processing Record 38 of Set 3 | dikson
# Processing Record 39 of Set 3 | mugur-aksy
# Processing Record 40 of Set 3 | mergui
# City not found. Skipping...
# Processing Record 41 of Set 3 | hambantota
# Processing Record 42 of Set 3 | torbay
# Processing Record 43 of Set 3 | constitucion
# Processing Record 44 of Set 3 | pochutla
# Processing Record 45 of Set 3 | nanortalik
# Processing Record 46 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 3 | bilma
# Processing Record 48 of Set 3 | erzin
# Processing Record 49 of Set 3 | kodiak
# Processing Record 50 of Set 3 | rangpur
# Processing Record 1 of Set 4 | tarija
# Processing Record 2 of Set 4 | namatanai
# Processing Record 3 of Set 4 | kaitangata
# Processing Record 4 of Set 4 | punta arenas
# Processing Record 5 of Set 4 | sambava
# Processing Record 6 of Set 4 | la ronge
# Processing Record 7 of Set 4 | amravati
# Processing Record 8 of Set 4 | san cristobal
# Processing Record 9 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 10 of Set 4 | codrington
# Processing Record 11 of Set 4 | san carlos de bariloche
# Processing Record 12 of Set 4 | maniitsoq
# Processing Record 13 of Set 4 | sisimiut
# Processing Record 14 of Set 4 | amalapuram
# Processing Record 15 of Set 4 | faanui
# Processing Record 16 of Set 4 | harper
# Processing Record 17 of Set 4 | upata
# Processing Record 18 of Set 4 | tuatapere
# Processing Record 19 of Set 4 | lompoc
# Processing Record 20 of Set 4 | tasiilaq
# Processing Record 21 of Set 4 | smolenka
# Processing Record 22 of Set 4 | dobryanka
# Processing Record 23 of Set 4 | sakakah
# Processing Record 24 of Set 4 | zomin
# Processing Record 25 of Set 4 | karratha
# Processing Record 26 of Set 4 | akdepe
# Processing Record 27 of Set 4 | ribeira grande
# Processing Record 28 of Set 4 | quelimane
# Processing Record 29 of Set 4 | scarborough
# Processing Record 30 of Set 4 | lavrentiya
# Processing Record 31 of Set 4 | fevralsk
# City not found. Skipping...
# Processing Record 32 of Set 4 | cap malheureux
# Processing Record 33 of Set 4 | benghazi
# Processing Record 34 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 4 | moose factory
# Processing Record 36 of Set 4 | pevek
# Processing Record 37 of Set 4 | bengkulu
# Processing Record 38 of Set 4 | tilichiki
# Processing Record 39 of Set 4 | hamilton
# Processing Record 40 of Set 4 | dire dawa
# Processing Record 41 of Set 4 | mahebourg
# Processing Record 42 of Set 4 | ranau
# Processing Record 43 of Set 4 | rapid valley
# Processing Record 44 of Set 4 | palkaka
# City not found. Skipping...
# Processing Record 45 of Set 4 | yuksekova
# Processing Record 46 of Set 4 | miracema do tocantins
# Processing Record 47 of Set 4 | cortes
# Processing Record 48 of Set 4 | ostrovnoy
# Processing Record 49 of Set 4 | sligo
# Processing Record 50 of Set 4 | kortkeros
# Processing Record 1 of Set 5 | providencia
# Processing Record 2 of Set 5 | norman wells
# Processing Record 3 of Set 5 | vangaindrano
# Processing Record 4 of Set 5 | oum hadjer
# Processing Record 5 of Set 5 | angoche
# Processing Record 6 of Set 5 | kaspiysk
# Processing Record 7 of Set 5 | lahat
# Processing Record 8 of Set 5 | poum
# Processing Record 9 of Set 5 | inderborskiy
# City not found. Skipping...
# Processing Record 10 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 5 | adrar
# Processing Record 12 of Set 5 | luderitz
# Processing Record 13 of Set 5 | esperance
# Processing Record 14 of Set 5 | carbonia
# Processing Record 15 of Set 5 | ilo
# Processing Record 16 of Set 5 | shubarshi
# Processing Record 17 of Set 5 | san juan
# Processing Record 18 of Set 5 | helena
# Processing Record 19 of Set 5 | mayumba
# Processing Record 20 of Set 5 | westport
# Processing Record 21 of Set 5 | neuquen
# Processing Record 22 of Set 5 | provideniya
# Processing Record 23 of Set 5 | lamu
# Processing Record 24 of Set 5 | nyimba
# Processing Record 25 of Set 5 | pitimbu
# Processing Record 26 of Set 5 | buraydah
# Processing Record 27 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 5 | cabo san lucas
# Processing Record 29 of Set 5 | yazykovo
# Processing Record 30 of Set 5 | dwarka
# Processing Record 31 of Set 5 | banda aceh
# Processing Record 32 of Set 5 | guanambi
# Processing Record 33 of Set 5 | anadyr
# Processing Record 34 of Set 5 | yerbogachen
# Processing Record 35 of Set 5 | guerrero negro
# Processing Record 36 of Set 5 | mehamn
# Processing Record 37 of Set 5 | puerto carreno
# Processing Record 38 of Set 5 | dromolaxia
# Processing Record 39 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 5 | maarianhamina
# Processing Record 41 of Set 5 | kamenka
# Processing Record 42 of Set 5 | broken hill
# Processing Record 43 of Set 5 | linjiang
# Processing Record 44 of Set 5 | pangnirtung
# Processing Record 45 of Set 5 | tazovskiy
# Processing Record 46 of Set 5 | mixtequilla
# City not found. Skipping...
# Processing Record 47 of Set 5 | coihaique
# Processing Record 48 of Set 5 | anloga
# Processing Record 49 of Set 5 | deogarh
# Processing Record 50 of Set 5 | saint george
# Processing Record 1 of Set 6 | blama
# Processing Record 2 of Set 6 | chuy
# Processing Record 3 of Set 6 | souillac
# Processing Record 4 of Set 6 | hasaki
# Processing Record 5 of Set 6 | hervey bay
# Processing Record 6 of Set 6 | komsomolskiy
# Processing Record 7 of Set 6 | darnah
# Processing Record 8 of Set 6 | flinders
# Processing Record 9 of Set 6 | muzhi
# Processing Record 10 of Set 6 | port augusta
# Processing Record 11 of Set 6 | sangar
# Processing Record 12 of Set 6 | coahuayana
# Processing Record 13 of Set 6 | muromtsevo
# Processing Record 14 of Set 6 | diffa
# Processing Record 15 of Set 6 | greeneville
# Processing Record 16 of Set 6 | samarai
# Processing Record 17 of Set 6 | palu
# Processing Record 18 of Set 6 | ambulu
# Processing Record 19 of Set 6 | kolyshley
# Processing Record 20 of Set 6 | saint andrews
# Processing Record 21 of Set 6 | bud
# Processing Record 22 of Set 6 | general roca
# Processing Record 23 of Set 6 | moussoro
# Processing Record 24 of Set 6 | georgetown
# Processing Record 25 of Set 6 | moron
# Processing Record 26 of Set 6 | sumbawa
# City not found. Skipping...
# Processing Record 27 of Set 6 | clyde river
# Processing Record 28 of Set 6 | mareeba
# Processing Record 29 of Set 6 | juneau
# Processing Record 30 of Set 6 | kachikau
# City not found. Skipping...
# Processing Record 31 of Set 6 | sioux lookout
# Processing Record 32 of Set 6 | mgachi
# Processing Record 33 of Set 6 | dunedin
# Processing Record 34 of Set 6 | belle fourche
# Processing Record 35 of Set 6 | haines junction
# Processing Record 36 of Set 6 | mombetsu
# Processing Record 37 of Set 6 | stephenville
# Processing Record 38 of Set 6 | beringovskiy
# Processing Record 39 of Set 6 | berlevag
# Processing Record 40 of Set 6 | monkey bay
# Processing Record 41 of Set 6 | the valley
# Processing Record 42 of Set 6 | vardo
# Processing Record 43 of Set 6 | otradnoye
# Processing Record 44 of Set 6 | kemijarvi
# Processing Record 45 of Set 6 | ourossogui
# Processing Record 46 of Set 6 | tevriz
# Processing Record 47 of Set 6 | diapaga
# Processing Record 48 of Set 6 | yulara
# Processing Record 49 of Set 6 | prince george
# Processing Record 50 of Set 6 | ninghai
# Processing Record 1 of Set 7 | ko samui
# Processing Record 2 of Set 7 | san ramon
# Processing Record 3 of Set 7 | tsiroanomandidy
# Processing Record 4 of Set 7 | cabedelo
# Processing Record 5 of Set 7 | talnakh
# Processing Record 6 of Set 7 | burnie
# Processing Record 7 of Set 7 | birjand
# Processing Record 8 of Set 7 | show low
# Processing Record 9 of Set 7 | leningradskiy
# Processing Record 10 of Set 7 | airai
# Processing Record 11 of Set 7 | labuhan
# Processing Record 12 of Set 7 | kieta
# Processing Record 13 of Set 7 | kawalu
# Processing Record 14 of Set 7 | daru
# Processing Record 15 of Set 7 | vila velha
# Processing Record 16 of Set 7 | acapulco
# Processing Record 17 of Set 7 | mizan teferi
# Processing Record 18 of Set 7 | novikovo
# Processing Record 19 of Set 7 | manggar
# Processing Record 20 of Set 7 | san patricio
# Processing Record 21 of Set 7 | iqaluit
# Processing Record 22 of Set 7 | bubaque
# Processing Record 23 of Set 7 | cherskiy
# Processing Record 24 of Set 7 | gamba
# Processing Record 25 of Set 7 | adre
# Processing Record 26 of Set 7 | bjornevatn
# Processing Record 27 of Set 7 | beyla
# Processing Record 28 of Set 7 | kudahuvadhoo
# Processing Record 29 of Set 7 | mount gambier
# Processing Record 30 of Set 7 | itarema
# Processing Record 31 of Set 7 | aykhal
# Processing Record 32 of Set 7 | castro
# Processing Record 33 of Set 7 | kununurra
# Processing Record 34 of Set 7 | matara
# Processing Record 35 of Set 7 | lieksa
# Processing Record 36 of Set 7 | narsaq
# Processing Record 37 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 38 of Set 7 | hami
# Processing Record 39 of Set 7 | kachiry
# Processing Record 40 of Set 7 | tapaua
# City not found. Skipping...
# Processing Record 41 of Set 7 | nikko
# Processing Record 42 of Set 7 | ixtapa
# Processing Record 43 of Set 7 | sao filipe
# Processing Record 44 of Set 7 | araouane
# Processing Record 45 of Set 7 | karpathos
# Processing Record 46 of Set 7 | aguimes
# Processing Record 47 of Set 7 | anuradhapura
# Processing Record 48 of Set 7 | miramar
# Processing Record 49 of Set 7 | malinyi
# Processing Record 50 of Set 7 | okato
# Processing Record 1 of Set 8 | bitung
# Processing Record 2 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 8 | waipawa
# Processing Record 4 of Set 8 | walvis bay
# Processing Record 5 of Set 8 | ramgarh
# Processing Record 6 of Set 8 | maceio
# Processing Record 7 of Set 8 | chumphon
# Processing Record 8 of Set 8 | hofn
# Processing Record 9 of Set 8 | rio grande
# Processing Record 10 of Set 8 | zalantun
# Processing Record 11 of Set 8 | puerto escondido
# Processing Record 12 of Set 8 | raga
# Processing Record 13 of Set 8 | naze
# Processing Record 14 of Set 8 | amboise
# Processing Record 15 of Set 8 | tiarei
# Processing Record 16 of Set 8 | odesskoye
# Processing Record 17 of Set 8 | bontang
# Processing Record 18 of Set 8 | trelew
# Processing Record 19 of Set 8 | clayton
# Processing Record 20 of Set 8 | nurobod
# Processing Record 21 of Set 8 | nikolayevka
# Processing Record 22 of Set 8 | olovyannaya
# Processing Record 23 of Set 8 | luganville
# Processing Record 24 of Set 8 | saint paul
# Processing Record 25 of Set 8 | santa maria
# Processing Record 26 of Set 8 | havre-saint-pierre
# Processing Record 27 of Set 8 | fort nelson
# Processing Record 28 of Set 8 | rumphi
# Processing Record 29 of Set 8 | smithers
# Processing Record 30 of Set 8 | vestmannaeyjar
# Processing Record 31 of Set 8 | belaya gora
# Processing Record 32 of Set 8 | rolim de moura
# City not found. Skipping...
# Processing Record 33 of Set 8 | diego de almagro
# Processing Record 34 of Set 8 | marsaxlokk
# Processing Record 35 of Set 8 | abu kamal
# Processing Record 36 of Set 8 | kanpur
# Processing Record 37 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 8 | garwa
# Processing Record 39 of Set 8 | port blair
# Processing Record 40 of Set 8 | shevchenkove
# Processing Record 41 of Set 8 | oriximina
# Processing Record 42 of Set 8 | akyab
# Processing Record 43 of Set 8 | shimoda
# Processing Record 44 of Set 8 | chico
# Processing Record 45 of Set 8 | acarau
# Processing Record 46 of Set 8 | tessalit
# Processing Record 47 of Set 8 | ormara
# Processing Record 48 of Set 8 | belomorsk
# Processing Record 49 of Set 8 | fare
# Processing Record 50 of Set 8 | chicama
# Processing Record 1 of Set 9 | bosaso
# Processing Record 2 of Set 9 | salalah
# Processing Record 3 of Set 9 | alofi
# Processing Record 4 of Set 9 | qujing
# Processing Record 5 of Set 9 | virginia beach
# Processing Record 6 of Set 9 | methven
# Processing Record 7 of Set 9 | rawson
# Processing Record 8 of Set 9 | puerto el triunfo
# Processing Record 9 of Set 9 | fevik
# Processing Record 10 of Set 9 | buchanan
# Processing Record 11 of Set 9 | luanda
# Processing Record 12 of Set 9 | bojnice
# Processing Record 13 of Set 9 | brewster
# Processing Record 14 of Set 9 | temaraia
# City not found. Skipping...
# Processing Record 15 of Set 9 | kuruman
# Processing Record 16 of Set 9 | nantucket
# Processing Record 17 of Set 9 | saint-augustin
# Processing Record 18 of Set 9 | fasa
# Processing Record 19 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 20 of Set 9 | tezu
# Processing Record 21 of Set 9 | krasnoarmeysk
# Processing Record 22 of Set 9 | nemuro
# Processing Record 23 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 24 of Set 9 | marawi
# Processing Record 25 of Set 9 | tucuman
# Processing Record 26 of Set 9 | auki
# Processing Record 27 of Set 9 | rio pardo
# Processing Record 28 of Set 9 | hare bay
# Processing Record 29 of Set 9 | voskresenskoye
# Processing Record 30 of Set 9 | starogard gdanski
# Processing Record 31 of Set 9 | tianpeng
# Processing Record 32 of Set 9 | altay
# Processing Record 33 of Set 9 | olean
# Processing Record 34 of Set 9 | tsabong
# Processing Record 35 of Set 9 | katsiveli
# City not found. Skipping...
# Processing Record 36 of Set 9 | xichang
# Processing Record 37 of Set 9 | klaksvik
# Processing Record 38 of Set 9 | troina
# Processing Record 39 of Set 9 | saskylakh
# Processing Record 40 of Set 9 | izumo
# Processing Record 41 of Set 9 | otoka
# Processing Record 42 of Set 9 | agua verde
# Processing Record 43 of Set 9 | vostok
# Processing Record 44 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 9 | grande prairie
# Processing Record 46 of Set 9 | angra
# City not found. Skipping...
# Processing Record 47 of Set 9 | pisco
# Processing Record 48 of Set 9 | rahden
# Processing Record 49 of Set 9 | sayyan
# Processing Record 50 of Set 9 | eirunepe
# Processing Record 1 of Set 10 | ust-nera
# Processing Record 2 of Set 10 | kosonsoy
# Processing Record 3 of Set 10 | marsh harbour
# Processing Record 4 of Set 10 | singaraja
# Processing Record 5 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 10 | kendari
# Processing Record 7 of Set 10 | wajima
# Processing Record 8 of Set 10 | alamogordo
# Processing Record 9 of Set 10 | along
# Processing Record 10 of Set 10 | tromso
# Processing Record 11 of Set 10 | bongandanga
# Processing Record 12 of Set 10 | bani walid
# Processing Record 13 of Set 10 | general pico
# Processing Record 14 of Set 10 | moranbah
# Processing Record 15 of Set 10 | muros
# Processing Record 16 of Set 10 | cedeno
# Processing Record 17 of Set 10 | sierra vista
# Processing Record 18 of Set 10 | amuntai
# Processing Record 19 of Set 10 | chapais
# Processing Record 20 of Set 10 | simplicio mendes
# Processing Record 21 of Set 10 | kloulklubed
# Processing Record 22 of Set 10 | porto santo
# Processing Record 23 of Set 10 | taoudenni
# Processing Record 24 of Set 10 | iguape
# Processing Record 25 of Set 10 | faya
# Processing Record 26 of Set 10 | svetlyy
# Processing Record 27 of Set 10 | boras
# Processing Record 28 of Set 10 | maragogi
# Processing Record 29 of Set 10 | arlit
# Processing Record 30 of Set 10 | roald
# Processing Record 31 of Set 10 | kota bahru
# Processing Record 32 of Set 10 | chumikan
# Processing Record 33 of Set 10 | aktash
# Processing Record 34 of Set 10 | santa cruz
# Processing Record 35 of Set 10 | shihezi
# Processing Record 36 of Set 10 | corum
# Processing Record 37 of Set 10 | uslar
# Processing Record 38 of Set 10 | tasbuget
# City not found. Skipping...
# Processing Record 39 of Set 10 | salta
# Processing Record 40 of Set 10 | lagoa
# Processing Record 41 of Set 10 | taunggyi
# Processing Record 42 of Set 10 | jalu
# Processing Record 43 of Set 10 | abu dhabi
# Processing Record 44 of Set 10 | ucar
# Processing Record 45 of Set 10 | itaituba
# Processing Record 46 of Set 10 | shelburne
# Processing Record 47 of Set 10 | ahipara
# Processing Record 48 of Set 10 | seoul
# Processing Record 49 of Set 10 | tecoanapa
# Processing Record 50 of Set 10 | lienz
# Processing Record 1 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 2 of Set 11 | ahar
# Processing Record 3 of Set 11 | fort abbas
# Processing Record 4 of Set 11 | kiama
# Processing Record 5 of Set 11 | caxito
# Processing Record 6 of Set 11 | vrable
# Processing Record 7 of Set 11 | inirida
# Processing Record 8 of Set 11 | ardistan
# City not found. Skipping...
# Processing Record 9 of Set 11 | durban
# Processing Record 10 of Set 11 | aitape
# Processing Record 11 of Set 11 | bandarbeyla
# Processing Record 12 of Set 11 | ketchenery
# City not found. Skipping...
# Processing Record 13 of Set 11 | charyshskoye
# Processing Record 14 of Set 11 | aktau
# Processing Record 15 of Set 11 | porto walter
# Processing Record 16 of Set 11 | drayton valley
# Processing Record 17 of Set 11 | nabire
# Processing Record 18 of Set 11 | benin
# Processing Record 19 of Set 11 | ariano irpino
# Processing Record 20 of Set 11 | samut prakan
# Processing Record 21 of Set 11 | addi ugri
# City not found. Skipping...
# Processing Record 22 of Set 11 | byron bay
# Processing Record 23 of Set 11 | iskateley
# Processing Record 24 of Set 11 | lodja
# Processing Record 25 of Set 11 | montelibano
# Processing Record 26 of Set 11 | touros
# Processing Record 27 of Set 11 | namibe
# Processing Record 28 of Set 11 | saint-leu
# Processing Record 29 of Set 11 | vermilion
# Processing Record 30 of Set 11 | srednekolymsk
# Processing Record 31 of Set 11 | kurashiki
# Processing Record 32 of Set 11 | barcelona
# Processing Record 33 of Set 11 | ondjiva
# Processing Record 34 of Set 11 | los llanos de aridane
# Processing Record 35 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 36 of Set 11 | norilsk
# Processing Record 37 of Set 11 | malakal
# Processing Record 38 of Set 11 | richards bay
# Processing Record 39 of Set 11 | toora-khem
# Processing Record 40 of Set 11 | isangel
# Processing Record 41 of Set 11 | yefira
# City not found. Skipping...
# Processing Record 42 of Set 11 | palmas
# Processing Record 43 of Set 11 | buin
# Processing Record 44 of Set 11 | moerai
# Processing Record 45 of Set 11 | lakatoro
# Processing Record 46 of Set 11 | krutinka
# Processing Record 47 of Set 11 | port hardy
# Processing Record 48 of Set 11 | vila franca do campo
# Processing Record 49 of Set 11 | kavieng
# Processing Record 50 of Set 11 | san quintin
# Processing Record 1 of Set 12 | matadi
# Processing Record 2 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 3 of Set 12 | plouzane
# Processing Record 4 of Set 12 | dukat
# Processing Record 5 of Set 12 | dunmore town
# Processing Record 6 of Set 12 | waddan
# Processing Record 7 of Set 12 | charters towers
# Processing Record 8 of Set 12 | half moon bay
# Processing Record 9 of Set 12 | ambon
# Processing Record 10 of Set 12 | joshimath
# Processing Record 11 of Set 12 | rach gia
# Processing Record 12 of Set 12 | mazagao
# Processing Record 13 of Set 12 | la palma
# Processing Record 14 of Set 12 | laela
# Processing Record 15 of Set 12 | shagonar
# Processing Record 16 of Set 12 | gat
# Processing Record 17 of Set 12 | colares
# Processing Record 18 of Set 12 | yumen
# Processing Record 19 of Set 12 | barth
# Processing Record 20 of Set 12 | genhe
# Processing Record 21 of Set 12 | mocuba
# Processing Record 22 of Set 12 | maloshuyka
# City not found. Skipping...
# Processing Record 23 of Set 12 | oussouye
# Processing Record 24 of Set 12 | meulaboh
# Processing Record 25 of Set 12 | ketchikan
# Processing Record 26 of Set 12 | susaki
# Processing Record 27 of Set 12 | denia
# Processing Record 28 of Set 12 | balkhash
# Processing Record 29 of Set 12 | krasnovishersk
# Processing Record 30 of Set 12 | te anau
# Processing Record 31 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 12 | tirumullaivasal
# Processing Record 33 of Set 12 | mitsamiouli
# Processing Record 34 of Set 12 | xining
# Processing Record 35 of Set 12 | gdov
# Processing Record 36 of Set 12 | fortuna
# Processing Record 37 of Set 12 | lethem
# Processing Record 38 of Set 12 | makakilo city
# Processing Record 39 of Set 12 | ambunti
# Processing Record 40 of Set 12 | port hedland
# Processing Record 41 of Set 12 | puerto baquerizo moreno
# Processing Record 42 of Set 12 | male
# Processing Record 43 of Set 12 | yenagoa
# Processing Record 44 of Set 12 | kutum
# Processing Record 45 of Set 12 | bargarh
# Processing Record 46 of Set 12 | sehithwa
# Processing Record 47 of Set 12 | toamasina
# Processing Record 48 of Set 12 | ballina
# Processing Record 49 of Set 12 | najran
# Processing Record 50 of Set 12 | pokhara
# Processing Record 1 of Set 13 | emerald
# Processing Record 2 of Set 13 | lapao
# Processing Record 3 of Set 13 | santa cruz de la palma
# Processing Record 4 of Set 13 | omsukchan
# Processing Record 5 of Set 13 | ignalina
# Processing Record 6 of Set 13 | snyder
# Processing Record 7 of Set 13 | abu samrah
# Processing Record 8 of Set 13 | stornoway
# Processing Record 9 of Set 13 | pangody
# Processing Record 10 of Set 13 | kolobrzeg
# Processing Record 11 of Set 13 | sao gabriel da cachoeira
# Processing Record 12 of Set 13 | sao miguel do iguacu
# Processing Record 13 of Set 13 | santa isabel
# Processing Record 14 of Set 13 | katsuura
# Processing Record 15 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 16 of Set 13 | vanavara
# Processing Record 17 of Set 13 | mogadishu
# Processing Record 18 of Set 13 | constantine
# Processing Record 19 of Set 13 | kuching
# Processing Record 20 of Set 13 | porto novo
# Processing Record 21 of Set 13 | potgietersrus
# City not found. Skipping...
# Processing Record 22 of Set 13 | coronel
# Processing Record 23 of Set 13 | saint anthony
# Processing Record 24 of Set 13 | usinsk
# Processing Record 25 of Set 13 | doka
# Processing Record 26 of Set 13 | salmas
# Processing Record 27 of Set 13 | carlos antonio lopez
# Processing Record 28 of Set 13 | makokou
# Processing Record 29 of Set 13 | vao
# Processing Record 30 of Set 13 | coquimbo
# Processing Record 31 of Set 13 | marzuq
# Processing Record 32 of Set 13 | champerico
# Processing Record 33 of Set 13 | kupang
# Processing Record 34 of Set 13 | kurduvadi
# Processing Record 35 of Set 13 | payo
# Processing Record 36 of Set 13 | beroroha
# Processing Record 37 of Set 13 | pingyi
# Processing Record 38 of Set 13 | parabel
# Processing Record 39 of Set 13 | saint-francois
# Processing Record 40 of Set 13 | suntar
# Processing Record 41 of Set 13 | armizonskoye
# Processing Record 42 of Set 13 | namuac
# Processing Record 43 of Set 13 | nioki
# Processing Record 44 of Set 13 | hanmer springs
# Processing Record 45 of Set 13 | gizo
# Processing Record 46 of Set 13 | rudnogorsk
# Processing Record 47 of Set 13 | oxford
# Processing Record 48 of Set 13 | yanggu
# Processing Record 49 of Set 13 | russell
# Processing Record 50 of Set 13 | abha
# Processing Record 1 of Set 14 | kimbe
# Processing Record 2 of Set 14 | lata
# Processing Record 3 of Set 14 | sapa
# Processing Record 4 of Set 14 | eureka
# Processing Record 5 of Set 14 | tsurib
# Processing Record 6 of Set 14 | itoman
# Processing Record 7 of Set 14 | praia da vitoria
# Processing Record 8 of Set 14 | tshikapa
# Processing Record 9 of Set 14 | viedma
# Processing Record 10 of Set 14 | doha
# Processing Record 11 of Set 14 | kushmurun
# Processing Record 12 of Set 14 | north myrtle beach
# Processing Record 13 of Set 14 | paita
# Processing Record 14 of Set 14 | san jose
# Processing Record 15 of Set 14 | naples
# Processing Record 16 of Set 14 | pavelets
# Processing Record 17 of Set 14 | puerto leguizamo
# Processing Record 18 of Set 14 | slave lake
# Processing Record 19 of Set 14 | alice town
# Processing Record 20 of Set 14 | aswan
# Processing Record 21 of Set 14 | ribas do rio pardo
# Processing Record 22 of Set 14 | petrolina
# Processing Record 23 of Set 14 | atyrau
# Processing Record 24 of Set 14 | americus
# Processing Record 25 of Set 14 | stephenville crossing
# Processing Record 26 of Set 14 | celestun
# Processing Record 27 of Set 14 | sukhodol
# Processing Record 28 of Set 14 | trairi
# Processing Record 29 of Set 14 | umm lajj
# Processing Record 30 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 31 of Set 14 | olafsvik
# Processing Record 32 of Set 14 | farmington
# Processing Record 33 of Set 14 | posse
# Processing Record 34 of Set 14 | misratah
# Processing Record 35 of Set 14 | boiro
# Processing Record 36 of Set 14 | tarabuco
# Processing Record 37 of Set 14 | bahia blanca
# Processing Record 38 of Set 14 | aracuai
# Processing Record 39 of Set 14 | beidao
# Processing Record 40 of Set 14 | sorland
# Processing Record 41 of Set 14 | letka
# Processing Record 42 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 43 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 44 of Set 14 | hobyo
# Processing Record 45 of Set 14 | zaozerne
# Processing Record 46 of Set 14 | henderson
# Processing Record 47 of Set 14 | rorvik
# Processing Record 48 of Set 14 | mana
# Processing Record 49 of Set 14 | vredendal
# Processing Record 50 of Set 14 | santa ana
# Processing Record 1 of Set 15 | itapetinga
# Processing Record 2 of Set 15 | aksarka
# Processing Record 3 of Set 15 | hai duong
# Processing Record 4 of Set 15 | union
# Processing Record 5 of Set 15 | aranyosapati
# Processing Record 6 of Set 15 | lazaro cardenas
# Processing Record 7 of Set 15 | gimli
# Processing Record 8 of Set 15 | north bend
# Processing Record 9 of Set 15 | comodoro rivadavia
# Processing Record 10 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 11 of Set 15 | nome
# Processing Record 12 of Set 15 | bulgan
# Processing Record 13 of Set 15 | shumikha
# Processing Record 14 of Set 15 | avera
# Processing Record 15 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 16 of Set 15 | isawa
# Processing Record 17 of Set 15 | sistranda
# Processing Record 18 of Set 15 | cepu
# Processing Record 19 of Set 15 | dickinson
# Processing Record 20 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 21 of Set 15 | saint-joseph
# Processing Record 22 of Set 15 | ukiah
# Processing Record 23 of Set 15 | humaita
# Processing Record 24 of Set 15 | gunjur
# Processing Record 25 of Set 15 | kaabong
# Processing Record 26 of Set 15 | yirol
# City not found. Skipping...
# Processing Record 27 of Set 15 | camacha
# Processing Record 28 of Set 15 | takoradi
# Processing Record 29 of Set 15 | imeni poliny osipenko
# Processing Record 30 of Set 15 | antofagasta
# Processing Record 31 of Set 15 | kuala krai
# City not found. Skipping...
# Processing Record 32 of Set 15 | kayes
# Processing Record 33 of Set 15 | dangriga
# Processing Record 34 of Set 15 | malwan
# City not found. Skipping...
# Processing Record 35 of Set 15 | bajo baudo
# City not found. Skipping...
# Processing Record 36 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 37 of Set 15 | buta
# Processing Record 38 of Set 15 | santa isabel do rio negro
# Processing Record 39 of Set 15 | menongue
# Processing Record 40 of Set 15 | bowling green
# Processing Record 41 of Set 15 | prachin buri
# Processing Record 42 of Set 15 | kindu
# Processing Record 43 of Set 15 | mocambique
# City not found. Skipping...
# Processing Record 44 of Set 15 | sakaiminato
# Processing Record 45 of Set 15 | talas
# Processing Record 46 of Set 15 | galeana
# Processing Record 47 of Set 15 | greytown
# Processing Record 48 of Set 15 | hisai
# Processing Record 49 of Set 15 | sao joao da barra
# Processing Record 50 of Set 15 | necochea
# Processing Record 1 of Set 16 | lolua
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len (city_data)
# Out:
# 689

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Ponta Do Sol  32.6667  -17.1000     66.70        87         100
# 1          Bluff -46.6000  168.3333     74.80        53          30
# 2      Busselton -33.6500  115.3333     88.59        35          29
# 3          Tiksi  71.6872  128.8694    -12.30       100         100
# 4       Lorengau  -2.0226  147.2712     83.79        79          81
# 5        Tautira -17.7333 -149.1500     82.42        78          27
# 6      Cape Town -33.9258   18.4232     68.41        78           0
# 7     Chokurdakh  70.6333  147.9167    -16.98        97         100
# 8      Fairbanks  64.8378 -147.7164     14.22        85          90
# 9  Mar Del Plata -38.0023  -57.5575     63.09        88           0
#
#    Wind Speed Country Current Description
# 0        7.92      PT     overcast clouds
# 1       12.97      NZ    scattered clouds
# 2        9.33      AU    scattered clouds
# 3        6.15      RU     overcast clouds
# 4        9.06      PG          light rain
# 5       16.75      PF          light rain
# 6        3.00      ZA           clear sky
# 7       10.56      RU     overcast clouds
# 8        0.00      US                snow
# 9        5.99      AR           clear sky

# %%
city_data_df["Lat"] = city_data_df["Lat"].map("{:.2f}".format)
city_data_df["Lng"] = city_data_df["Lng"].map("{:.2f}".format)
city_data_df
# Out:
#                   City     Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0         Ponta Do Sol   32.67   -17.10     66.70        87         100
# 1                Bluff  -46.60   168.33     74.80        53          30
# 2            Busselton  -33.65   115.33     88.59        35          29
# 3                Tiksi   71.69   128.87    -12.30       100         100
# 4             Lorengau   -2.02   147.27     83.79        79          81
# ..                 ...     ...      ...       ...       ...         ...
# 684            Galeana   24.83  -100.07     60.64        54           0
# 685           Greytown  -29.06    30.59     57.87        98          88
# 686              Hisai   34.67   136.47     38.79        70          64
# 687  Sao Joao Da Barra  -21.64   -41.05     69.37        79           0
# 688           Necochea  -38.55   -58.74     57.04        74           0
#
#      Wind Speed Country Current Description
# 0          7.92      PT     overcast clouds
# 1         12.97      NZ    scattered clouds
# 2          9.33      AU    scattered clouds
# 3          6.15      RU     overcast clouds
# 4          9.06      PG          light rain
# ..          ...     ...                 ...
# 684        0.83      MX           clear sky
# 685        1.81      ZA     overcast clouds
# 686       15.93      JP       broken clouds
# 687        3.44      BR           clear sky
# 688        0.89      AR           clear sky
#
# [689 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
city_data_df.notnull().sum()
# Out:
# City                   689
# Lat                    689
# Lng                    689
# Max Temp               689
# Humidity               689
# Cloudiness             689
# Wind Speed             689
# Country                689
# Current Description    689
# dtype: int64

# %%
#Add the data to a list in a dictionary format and then convert the list to a DataFrame.
city_data_df = pd.DataFrame(city_data)


#Reorder columns as City, Country, Date, Lat, Lng, Max Temp, Humidity, Cloudiness, and Wind Speed
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity", "Cloudiness","Wind Speed","Current Description"]

#assign city_data_df with new column order
city_data_df = city_data_df[new_column_order]

# Display DataFrame
city_data_df
# Out:
#                   City Country      Lat       Lng  Max Temp  Humidity  \
# 0         Ponta Do Sol      PT  32.6667  -17.1000     66.70        87
# 1                Bluff      NZ -46.6000  168.3333     74.80        53
# 2            Busselton      AU -33.6500  115.3333     88.59        35
# 3                Tiksi      RU  71.6872  128.8694    -12.30       100
# 4             Lorengau      PG  -2.0226  147.2712     83.79        79
# ..                 ...     ...      ...       ...       ...       ...
# 684            Galeana      MX  24.8333 -100.0667     60.64        54
# 685           Greytown      ZA -29.0642   30.5928     57.87        98
# 686              Hisai      JP  34.6667  136.4667     38.79        70
# 687  Sao Joao Da Barra      BR -21.6403  -41.0511     69.37        79
# 688           Necochea      AR -38.5473  -58.7368     57.04        74
#
#      Cloudiness  Wind Speed Current Description
# 0           100        7.92     overcast clouds
# 1            30       12.97    scattered clouds
# 2            29        9.33    scattered clouds
# 3           100        6.15     overcast clouds
# 4            81        9.06          light rain
# ..          ...         ...                 ...
# 684           0        0.83           clear sky
# 685          88        1.81     overcast clouds
# 686          64       15.93       broken clouds
# 687           0        3.44           clear sky
# 688           0        0.89           clear sky
#
# [689 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
